# %% [markdown]
# # Notebook 1

# %%
# standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
games_df   = pd.read_csv('./data/games.csv')
plays_df   = pd.read_csv('./data/plays.csv')
pff_df     = pd.read_csv('./data/PFFScoutingData.csv')
track_2018 = pd.read_csv('./data/tracking2018.csv')
# track_2019 = pd.read_csv('./data/tracking2019.csv')
# track_2020 = pd.read_csv('./data/tracking2020.csv')

# %% [markdown]
# ## Check for Nulls

# %%
games_df.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2018090600    2018     1  09/06/2018        20:20:00          PHI
# 1  2018090900    2018     1  09/09/2018        13:00:00          BAL
# 2  2018090901    2018     1  09/09/2018        13:00:00          CLE
# 3  2018090902    2018     1  09/09/2018        13:00:00          IND
# 4  2018090903    2018     1  09/09/2018        13:00:00          MIA
#
#   visitorTeamAbbr
# 0             ATL
# 1             BUF
# 2             PIT
# 3             CIN
# 4             TEN

# %%
games_df.shape
# Out:
# (764, 7)

# %%
games_df.isna().sum()
# Out:
# gameId             0
# season             0
# week               0
# gameDate           0
# gameTimeEastern    0
# homeTeamAbbr       0
# visitorTeamAbbr    0
# dtype: int64

# %%
games_df['gameTimeEastern'].value_counts()
# Out:
# 13:00:00    403
# 16:25:00    119
# 20:20:00     95
# 16:05:00     71
# 20:15:00     47
# 16:30:00      9
# 09:30:00      4
# 19:10:00      3
# 12:30:00      3
# 22:20:00      3
# 17:00:00      2
# 19:00:00      1
# 20:05:00      1
# 19:05:00      1
# 21:00:00      1
# 15:40:00      1
# Name: gameTimeEastern, dtype: int64

# %%
plays_df.columns
# Out:
# Index(['gameId', 'playId', 'playDescription', 'quarter', 'down', 'yardsToGo',
#        'possessionTeam', 'specialTeamsPlayType', 'specialTeamsResult',
#        'kickerId', 'returnerId', 'kickBlockerId', 'yardlineSide',
#        'yardlineNumber', 'gameClock', 'penaltyCodes', 'penaltyJerseyNumbers',
#        'penaltyYards', 'preSnapHomeScore', 'preSnapVisitorScore', 'passResult',
#        'kickLength', 'kickReturnYardage', 'playResult',
#        'absoluteYardlineNumber'],
#       dtype='object')

# %%
plays_df['specialTeamsPlayType'].value_counts()
# Out:
# Kickoff        7843
# Punt           5991
# Extra Point    3488
# Field Goal     2657
# Name: specialTeamsPlayType, dtype: int64

# %%
plays_df['kickLength'].value_counts()
# Out:
# 75.0    2015
# 70.0     583
# 74.0     540
# 67.0     401
# 66.0     389
#         ...
# 2.0        2
# 77.0       1
# 88.0       1
# 76.0       1
# 90.0       1
# Name: kickLength, Length: 79, dtype: int64

# %%
plays_df[(plays_df['specialTeamsPlayType'] == 'Field Goal') & (plays_df['specialTeamsResult'] == 'Kick Attempt Good') & 
         (plays_df['kickLength'] >= 50)]
# Out:
#            gameId  playId                                    playDescription  \
# 8      2018090600    1587  (2:13) M.Bryant 52 yard field goal is GOOD, Ce...
# 103    2018090902    2084  (:06) A.Vinatieri 51 yard field goal is GOOD, ...
# 144    2018090903    4143  (:16) (Field Goal formation) R.Succop 53 yard ...
# 386    2018091300    3081  (12:35) J.Tucker 55 yard field goal is GOOD, C...
# 527    2018091604    3196  (10:11) J.Myers 55 yard field goal is GOOD, Ce...
# ...           ...     ...                                                ...
# 19458  2020122711    1453  (9:38) M.Gay 51 yard field goal is GOOD, Cente...
# 19693  2021010305    1462  (7:18) M.Prater 54 yard field goal is GOOD, Ce...
# 19768  2021010308    2312  (:04) G.Zuerlein 57 yard field goal is GOOD, C...
# 19777  2021010308    3776  (6:32) G.Gano 50 yard field goal is GOOD, Cent...
# 19891  2021010312    4036  (:22) K.Fairbairn 51 yard field goal is GOOD, ...
#
# ...
